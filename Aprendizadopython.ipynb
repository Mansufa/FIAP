# %%
print("Hello world")
# Out:
# Hello world

# %%
import requests

url = 'https://raw.githubusercontent.com/guilhermeonrails/api-imersao-ia/main/words.json'
resposta = requests.get(url)
data = resposta.json()
len(data)
# Out:
# 43

# %%
data[0]
# Out:
# {'palavra': 'python',
#  'dica': 'automatizar tarefas e desenvolver aplicações web.'}

# %%
type(data)
# Out:
# list

# %%
import random

# %%
random.choice(data)
# Out:
# {'palavra': 'node',
#  'dica': 'criar aplicativos de servidor escaláveis e de alta performance.'}

# %%
valor_secreto = random.choice(data)
palavra_secreta = valor_secreto['palavra']
dica = valor_secreto['dica']
print(f'A palavra secreta tem {len(palavra_secreta)} letras -> {dica}')
# Out:
# A palavra secreta tem 4 letras -> desenvolver aplicações empresariais e para dispositivos móveis.
